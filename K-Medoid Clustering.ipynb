# %%
from openpyxl import load_workbook
import pandas as pd
import numpy as np

# %%
datadariexcel = pd.read_excel("data kp.xlsx")
datadariexcel
# Out:
#         NO         KODE                NAMA MAHASISWA         NIM  \
# 0      1.0  001/KP/2000                  Budi Wiyarno    96534008
# 1      2.0  002/KP/2000                Suryana Syamsu    96534007
# 2      3.0  003/KP/2000                   Agis Sugiri    96534006
# 3      4.0  004/KP/2000              Iip  S. Iskandar    99534002
# 4      NaN          NaN                           NaN         NaN
# 5      NaN          NaN                           NaN         NaN
# 6      5.0  005/KP/2001                           NaN    97534013
# 7      NaN          NaN             Muhimmatul Anista         NaN
# 8      NaN          NaN                    Mukhlisin     97534016
# 9      NaN          NaN                           NaN         NaN
# 10     NaN          NaN                           NaN         NaN
# 11     NaN          NaN                           NaN         NaN
# 12     6.0  006/KP/2001                 Slamet Riyadi    96534009
# ...

# %%
mengambilsampel = datadariexcel["JUDUL LAPORAN"]
mengambilsampel
# Out:
# 0      Laporan Kerja Praktek pada Departemen Polymeri...
# 1      Laporan Kerja Praktek pada Departemen Polymeri...
# 2      Proses Pembuatan Bahan Peledak di PT. DAHANA (...
# 3                                                    NaN
# 4      Proses Pembuatan Kertas di PT. KERTAS BLABAK M...
# 5                                                    NaN
# 6      Proses Pembuatan Semen di PT. SEMEN GRESIK (pe...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13     Laporan Kerja Praktek pada Departemen Polymeri...
# 14                                                   NaN
# 15                                                   NaN
# ...

# %% [markdown]
# ## Preprocessing

# %%
from nltk.tokenize import word_tokenize
isidari_token = []
for isitoken in datadariexcel:
    katayangadaditoken = word_tokenize(isitoken)
    isidari_token.append(katayangadaditoken)
    print(katayangadaditoken)
# Out:
# ['NO']
# ['KODE']
# ['NAMA', 'MAHASISWA']
# ['NIM']
# ['JUDUL', 'LAPORAN']
